# %%
# !pip install ultralytics
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-gpu (c:\users\fraja\appdata\roaming\python\python38\site-packages)

# %%
import os
from ultralytics import YOLO
from IPython.display import display, Image

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3060'

# %%
# %cd G:/
# Out:
# G:\

# %%
model = YOLO("yolov8s.pt")

results = model.train(data="custom.yaml", epochs=3, imgsz=224,device=0, batch=2)
# Out:
# Ultralytics YOLOv8.0.132  Python-3.8.17 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
#                                                             CUDA:1 (NVIDIA GeForce GTX 1060 3GB, 3072MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= custom.yaml epochs=3 imgsz=224  device=0  plots=True batch = 2

# %%
Image(filename='G:runs/detect/train11/confusion_matrix.png', width=600)

# %%
Image(filename='G:runs/detect/train11/results.png', width=600)
