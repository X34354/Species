# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 627.5/627.5 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# !pip install utils

# %%
import os
from ultralytics import YOLO
from IPython.display import display, Image
import utils

# %%
# !unzip -q /content/train_data.zip -d /content/

# %%
# !yolo task=detect mode=train model=yolov8x.pt data= custom.yaml batch = 64 epochs=30 imgsz=224 plots=True
# Out:
# ...
# 100% 131M/131M [00:00<00:00, 219MB/s]
# Ultralytics YOLOv8.0.132 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename='/content/runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(filename='/content/runs/detect/train4/results.png', width=600)
