# %%
import pandas as pd 
import numpy as np
import os

# %%
directory = 'G:/'
lst = os.listdir(directory)

# %%
base = pd.read_excel('C:/Users/fraja/Documents/pista/base/Base.xlsx')

# %%
#check colums
base.columns
# Out:
# Index(['File', 'Date_Time', 'StationID', 'SpeciesID', 'Temperature',
#        'Individuals', 'Sex', 'Water_Use', 'Way_of_use', 'Duration'],
#       dtype='object')

# %%
base['SpeciesID'].value_counts()
# Out:
# SpeciesID
# Crax rubra                12779
# Pecari tajacu              3591
# No animal                  2714
# Hylocichla mustelina       1871
# Meleagris ocellata         1467
#                           ...
# STRIGIDAE                     1
# Trochilidae                   1
# Scolopacidae                  1
# Glaucidium brasilianum        1
# Apodiformes                   1
# Name: count, Length: 161, dtype: int64

# %%
#we reviewed the distribution of our database
base['SpeciesID'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='SpeciesID'>

# %%
#We see that there are 161 species that have been registered but many only once, in this phase we will only focus on the 35 most relevant species for the project
df_counts  = base['SpeciesID'].value_counts().to_frame()

# %%
df_counts[ df_counts['count'] <= 10 ]
# Out:
#                         count
# SpeciesID
# Leopardus wiedii           10
# Ardea alba                 10
# Didelphis                   9
# Habia fuscicauda            9
# Sciurus yucatanensis        9
# ...                       ...
# STRIGIDAE                   1
# Trochilidae                 1
# Scolopacidae                1
# Glaucidium brasilianum      1
# Apodiformes                 1
#
# [85 rows x 1 columns]
